# %%
import re
from datetime import datetime, timedelta
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

input_csv_dir = 'cpu_analysis'
input_csv = 'nyucs003-osd-compute-2-20180907-000000.csv_interrupts_sec.csv'
#df = pd.read_csv(input_csv, delimiter=" ", infer_datetime_format=True)
df = pd.read_csv(input_csv_dir + '/' + input_csv, delimiter=" ")
df['timestamp'] = pd.to_datetime(df['#Date-Time'])
df = df.set_index('timestamp')
df.head()

df.plot.line(figsize=(17,4.5), legend='reverse')
plt.title(input_csv, color='black')
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

plt.savefig('testchad.pdf')
